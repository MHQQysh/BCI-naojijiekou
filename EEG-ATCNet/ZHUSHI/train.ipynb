# %%
# 1
import os # 导入os模块，用于操作系统相关功能，比如文件路径操作
import time # 导入time模块，用于时间相关功能，比如计算程序运行时间
import numpy as np # 导入numpy库，并as np，用于进行科学计算，特别是数组和矩阵操作
import matplotlib.pyplot as plt # 导入matplotlib.pyplot模块，并as plt，用于绘制图表

import tensorflow as tf # 导入tensorflow库，用于构建和训练机器学习模型

from tensorflow.keras.optimizers import Adam # 从tensorflow.keras.optimizers导入Adam优化器
from tensorflow.keras.losses import categorical_crossentropy # 从tensorflow.keras.losses导入categorical_crossentropy损失函数
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau # 从tensorflow.keras.callbacks导入回调函数，用于在训练期间执行特定操作
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay # 从sklearn.metrics导入评估指标，用于计算混淆矩阵、准确率等
from sklearn.metrics import cohen_kappa_score # 从sklearn.metrics导入cohen_kappa_score，用于计算Cohen's Kappa系数

import models # 导入自定义的models模块，其中包含不同的神经网络模型定义
from preprocess import get_data # 从preprocess模块导入get_data函数，用于数据预处理和加载
# from keras.utils.vis_utils import plot_model # 注释掉的代码，可能是用于可视化模型结构
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import time # 导入time模块，用于时间相关功能，比如计算程序运行时间
#       4 import numpy as np # 导入numpy库，并as np，用于进行科学计算，特别是数组和矩阵操作
# ----> 5 import matplotlib.pyplot as plt # 导入matplotlib.pyplot模块，并as plt，用于绘制图表
#       7 import tensorflow as tf # 导入tensorflow库，用于构建和训练机器学习模型
#       9 from tensorflow.keras.optimizers import Adam # 从tensorflow.keras.optimizers导入Adam优化器
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 8.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.9 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
# ...
